# %%
from functions import *

# %%
# Path for the downloaded data.
path = '/home/smurf/solo/data/'

# %%
event_onset = Event(spacecraft='solo', sensor='ept', data_level='l2', species='e', start_date=20200710, end_date=20200711, data_path=path)

# %%
event_onset.analyse(viewing='sun', bg_start=0, bg_length=5, channels=[1, 2], resample_period='10min', yscale='log', cusum_window=30, x_sigma=4)
# Out:
# ##### >Energy channels< #####
# 0.0330 - 0.0380 MeV
# #############################
#
# ##### >Flux peak< #####
#                             flux
# Time
# 2020-07-11 02:55:00  2677.246582
# #######################
#
# ##### >Onset time< #####
# 2020-07-11 02:25:00
# ########################
#
# ##### >Mean of background intensity< #####
# 196.53316
# ##########################################
#
# ##### >Std of background intensity< #####
# 78.88517
# #########################################
#
# ##### >Particle species< #####
# electrons
# ##############################

# %%
for viewing in ['sun', 'asun', 'north', 'south']:
    event_onset.analyse(viewing=viewing, bg_start=0, bg_length=5, channels=[1, 2], resample_period='10min', yscale='log', cusum_window=30)
# Out:
# ##### >Energy channels< #####
# 0.0330 - 0.0380 MeV
# #############################
#
# ##### >Flux peak< #####
#                             flux
# Time
# 2020-07-11 02:55:00  2677.246582
# #######################
#
# ##### >Onset time< #####
# 2020-07-11 02:25:00
# ########################
#
# ##### >Mean of background intensity< #####
# 196.53316
# ##########################################
#
# ##### >Std of background intensity< #####
# 78.88517
# #########################################
#
# ##### >Particle species< #####
# electrons
# ##############################
# ##### >Energy channels< #####
# 0.0330 - 0.0380 MeV
# #############################
#
# ##### >Flux peak< #####
#                             flux
# Time
# 2020-07-11 03:35:00  1535.120728
# #######################
#
# ##### >Onset time< #####
# 2020-07-11 02:55:00
# ########################
#
# ##### >Mean of background intensity< #####
# 388.61636
# ##########################################
#
# ...
