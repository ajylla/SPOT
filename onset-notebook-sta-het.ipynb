# %%
from functions import *

# %%
# Path for the downloaded data.
path = '/home/gieseler/uni/temp_data/'

# %%
event_onset = Event(spacecraft='sta', sensor='het', data_level='l2', species='p', start_date=datetime.date(2021,10,28), end_date=datetime.date(2021,10,29), data_path=path)
# Out:
# Files Downloaded: 100%|██████████| 1/1 [00:00<00:00,  1.29file/s]

# %%
event_onset.current_energies
# Out:
# {'Electron_Bins_Text': array([['0.7 - 1.4 MeV'],
#         ['1.4 - 2.8 MeV'],
#         ['2.8 - 4.0 MeV']], dtype='<U13'),
#  'Electron_Flux_UNITS': '#/(cm2-steradian-second-MeV/nucleon) ',
#  'Electron_Flux_FILLVAL': -1e+31,
#  'Proton_Bins_Text': array([['13.6 - 15.1 MeV '],
#         ['15.0 - 17.1 MeV '],
#         ['17.0 - 19.3 MeV '],
#         ['20.8 - 23.8 MeV '],
#         ['23.8 - 26.4 MeV '],
#         ['26.3 - 29.7 MeV '],
#         ['29.6 - 33. 4 MeV'],
#         ['33.4 - 35.8 MeV '],
#         ['35.6 - 40.5 MeV '],
#         ['40 - 60 MeV     '],
#         ['60 - 100 MeV    ']], dtype='<U16'),
#  'Proton_Flux_UNITS': '#/(cm2-steradian-second-MeV/nucleon) ',
#  'Proton_Flux_FILLVAL': -1e+31,
#  'channels_dict_df_e':       ch_strings  lower_E  upper_E   DE    mean_E
#  0  0.7 - 1.4 MeV      0.7      1.4  0.7  0.989949
#  1  1.4 - 2.8 MeV      1.4      2.8  1.4  1.979899
#  2  2.8 - 4.0 MeV      2.8      4.0  1.2  3.346640,
# ...

# %%
event_onset.analyse(viewing='', bg_start=0, bg_length=5, channels=[5,8], resample_period='1min', yscale='log', cusum_window=30)
# Out:
# ##### >Energy channels< #####
# 26.3 - 40.5 MeV
# #############################
#
# ##### >Flux peak< #####
# Epoch
# 2021-10-28 18:11:30    8.138157
# Freq: T, dtype: float32
# #######################
#
# ##### >Onset time< #####
# 2021-10-28 16:11:30
# ########################
#
# ##### >Mean of background intensity< #####
# 7.5609336e-05
# ##########################################
#
# ##### >Std of background intensity< #####
# 0.00037044857
# #########################################
#
# ##### >Particle species< #####
# ions
# ##############################
# (Epoch
#  2021-10-28 00:00:30    0.000000
#  2021-10-28 00:01:30    0.000000
#  2021-10-28 00:02:30    0.000000
#  2021-10-28 00:03:30    0.000000
#  2021-10-28 00:04:30    0.000000
#                           ...
#  2021-10-28 23:55:30    3.763533
#  2021-10-28 23:56:30    3.574082
#  2021-10-28 23:57:30    3.578004
#  2021-10-28 23:58:30    3.706702
#  2021-10-28 23:59:30    3.599110
# ...
