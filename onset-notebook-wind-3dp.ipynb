# %%
from onset_functions import *
# Out:
# time: 1.1 s (started: 2022-07-01 17:04:53 +03:00)

# %%
# Path for the downloaded data.
path = '/home/gieseler/uni/temp_data/'
path = '/home/gieseler/uni/wind/data'
# Out:
# time: 493 µs (started: 2022-07-01 17:04:54 +03:00)

# %%
event_onset = Event(spacecraft='wind', sensor='3dp', data_level='l2', species='e', start_date=datetime.date(2021,10,28), end_date=datetime.date(2021,10,30), data_path=path, threshold=None)
# Out:
# time: 6.17 s (started: 2022-07-01 17:09:45 +03:00)

# %%
event_onset.current_e_energies
# Out:
# {'channels_dict_df':                  mean_E             DE        lower_E        upper_E  \
#  ENERGY_0   27053.158203    8115.947754   18937.210938   35169.105469
#  ENERGY_1   40086.781250   12026.035156   28060.746094   52112.816406
#  ENERGY_2   65990.585938   19797.175781   46193.410156   85787.765625
#  ENERGY_3  108046.867188   32414.060547   75632.804688  140460.921875
#  ENERGY_4  181612.375000   54483.714844  127128.656250  236096.093750
#  ENERGY_5  309291.781250   92787.539062  216504.250000  402079.312500
#  ENERGY_6  515545.500000  154663.656250  360881.843750  670209.125000
#
#                      Bins_Text
#  ENERGY_0    18.94 - 35.17 keV
#  ENERGY_1    28.06 - 52.11 keV
#  ENERGY_2    46.19 - 85.79 keV
#  ENERGY_3   75.63 - 140.46 keV
#  ENERGY_4   127.13 - 236.1 keV
#  ENERGY_5   216.5 - 402.08 keV
#  ENERGY_6  360.88 - 670.21 keV  ,
#  'APPROX_ENERGY_LABELS': array([['EnergyCh1_Often~27000eV '],
#         ['EnergyCh2_Often~40500eV '],
# ...

# %%
event_onset.analyse(viewing='2', bg_start=0, bg_length=5, channels=[3], resample_period=None, yscale='log', cusum_window=30)
# Out:
# ##### >Energy channels< #####
# 75.63 - 140.46 keV
# #############################
#
# ##### >Flux peak< #####
# Time
# 2021-10-28 03:43:08.359    268711.5
# Name: FLUX_E3_P2, dtype: float32
# #######################
#
# ##### >Onset time< #####
# 2021-10-28 16:41:03.852000
# ########################
#
# ##### >Mean of background intensity< #####
# 315.02133
# ##########################################
#
# ##### >Std of background intensity< #####
# 8786.914
# #########################################
#
# ##### >Particle species< #####
# electrons
# ##############################
# (Time
#  2021-10-28 00:00:05.959      27.841917
#  2021-10-28 00:00:18.489      23.457176
#  2021-10-28 00:00:31.020      16.705151
#  2021-10-28 00:00:43.550      49.151752
#  2021-10-28 00:05:44.277      34.324451
#                                ...
#  2021-10-29 23:59:09.810    3215.073486
#  2021-10-29 23:59:22.341    3730.436279
#  2021-10-29 23:59:34.871    3730.436279
# ...

# %%
event_onset = Event(spacecraft='wind', sensor='3dp', data_level='l2', species='e', start_date=datetime.date(2021,10,28), end_date=datetime.date(2021,10,30), data_path=path, threshold=0.1)
event_onset.analyse(viewing='2', bg_start=0, bg_length=5, channels=[3], resample_period=None, yscale='log', cusum_window=30)
# Out:
# ##### >Energy channels< #####
# 75.63 - 140.46 keV
# #############################
#
# ##### >Flux peak< #####
# Time
# 2021-10-29 01:31:55.819    5411.407715
# Name: FLUX_E3_P2, dtype: float32
# #######################
#
# ##### >Onset time< #####
# 2021-10-28 16:17:02.870000
# ########################
#
# ##### >Mean of background intensity< #####
# 27.351
# ##########################################
#
# ##### >Std of background intensity< #####
# 11.3817215
# #########################################
#
# ##### >Particle species< #####
# electrons
# ##############################
# (Time
#  2021-10-28 00:00:05.959      27.841917
#  2021-10-28 00:00:18.489      23.457176
#  2021-10-28 00:00:31.020      16.705151
#  2021-10-28 00:00:43.550      49.151752
#  2021-10-28 00:05:44.277      34.324451
#                                ...
#  2021-10-29 23:59:09.810    3215.073486
#  2021-10-29 23:59:22.341    3730.436279
#  2021-10-29 23:59:34.871    3730.436279
# ...
